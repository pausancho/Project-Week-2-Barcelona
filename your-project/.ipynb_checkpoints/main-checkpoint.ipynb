# %% [markdown]
# # Ironhack Data Analytics Project2

# %% [markdown]
# ## Barcelona citizens with ages +60

# %%
import pandas as pd

# %%
url_padro = "https://opendata-ajuntament.barcelona.cat/data/dataset/9e93c1db-118a-4520-99e6-b3b955c33758/resource/61d91b31-9ba9-45ca-9cc3-47bf99555b4b/download/2020_padro_edat_any_a_any_per_sexe.csv"

# %%
padro = pd.read_csv(url_padro)

# %%
padro
# Out:
#         Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0      2020               1  Ciutat Vella           1
# 1      2020               1  Ciutat Vella           2
# 2      2020               1  Ciutat Vella           3
# 3      2020               1  Ciutat Vella           4
# 4      2020               2      Eixample           5
# ...     ...             ...           ...         ...
# 14741  2020              10    Sant Martí          69
# 14742  2020              10    Sant Martí          70
# 14743  2020              10    Sant Martí          71
# 14744  2020              10    Sant Martí          72
# 14745  2020              10    Sant Martí          73
#
#                                           Nom_Barri  Sexe  Edat_any_a_any  \
# 0                                          el Raval  Dona          0 anys
# 1                                    el Barri Gòtic  Dona          0 anys
# 2                                    la Barceloneta  Dona          0 anys
# 3             Sant Pere, Santa Caterina i la Ribera  Dona          0 anys
# 4                                     el Fort Pienc  Dona          0 anys
# ...                                             ...   ...             ...
# 14741  Diagonal Mar i el Front Marítim del Poblenou  Home  100 anys i més
# 14742                         el Besòs i el Maresme  Home  100 anys i més
# 14743                       Provençals del Poblenou  Home  100 anys i més
# 14744                      Sant Martí de Provençals  Home  100 anys i més
# 14745                           la Verneda i la Pau  Home  100 anys i més
#
#        Nombre
# 0         203
# 1          59
# 2          36
# 3          59
# 4          98
# ...       ...
# 14741       1
# 14742       1
# 14743       0
# 14744       1
# 14745       2
#
# [14746 rows x 8 columns]

# %%
# Adding a key column to the data set

# %%
padro["key"] = range(1, len(padro) + 1)

# %%
padro.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2020               1  Ciutat Vella           1
# 1  2020               1  Ciutat Vella           2
# 2  2020               1  Ciutat Vella           3
# 3  2020               1  Ciutat Vella           4
# 4  2020               2      Eixample           5
#
#                                Nom_Barri  Sexe Edat_any_a_any  Nombre  key
# 0                               el Raval  Dona         0 anys     203    1
# 1                         el Barri Gòtic  Dona         0 anys      59    2
# 2                         la Barceloneta  Dona         0 anys      36    3
# 3  Sant Pere, Santa Caterina i la Ribera  Dona         0 anys      59    4
# 4                          el Fort Pienc  Dona         0 anys      98    5

# %%
padro.columns
# Out:
# Index(['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
#        'Sexe', 'Edat_any_a_any', 'Nombre', 'key'],
#       dtype='object')

# %%
padro_columns = ['any', 'codi_districte', 'nom_districte', 'codi_barri', 'nom_barri',
       'sexe', 'edat', 'nombre', "key"]

# %%
padro.columns = padro_columns

# %%
padro.head()
# Out:
#     any  codi_districte nom_districte  codi_barri  \
# 0  2020               1  Ciutat Vella           1
# 1  2020               1  Ciutat Vella           2
# 2  2020               1  Ciutat Vella           3
# 3  2020               1  Ciutat Vella           4
# 4  2020               2      Eixample           5
#
#                                nom_barri  sexe    edat  nombre  key
# 0                               el Raval  Dona  0 anys     203    1
# 1                         el Barri Gòtic  Dona  0 anys      59    2
# 2                         la Barceloneta  Dona  0 anys      36    3
# 3  Sant Pere, Santa Caterina i la Ribera  Dona  0 anys      59    4
# 4                          el Fort Pienc  Dona  0 anys      98    5

# %%
years = pd.DataFrame(padro["edat"].str.split(" ", 1).tolist(),columns=["edats", "ref"])

# %%
years["key"] = range(1, len(years) + 1)

# %%
years
# Out:
#       edats         ref    key
# 0         0        anys      1
# 1         0        anys      2
# 2         0        anys      3
# 3         0        anys      4
# 4         0        anys      5
# ...     ...         ...    ...
# 14741   100  anys i més  14742
# 14742   100  anys i més  14743
# 14743   100  anys i més  14744
# 14744   100  anys i més  14745
# 14745   100  anys i més  14746
#
# [14746 rows x 3 columns]

# %%
# Mergin both data sets with the new column for the ages

# %%
padro_merge = pd.merge(padro, years, on='key')

# %%
padro_merge.head()
# Out:
#     any  codi_districte nom_districte  codi_barri  \
# 0  2020               1  Ciutat Vella           1
# 1  2020               1  Ciutat Vella           2
# 2  2020               1  Ciutat Vella           3
# 3  2020               1  Ciutat Vella           4
# 4  2020               2      Eixample           5
#
#                                nom_barri  sexe    edat  nombre  key edats  \
# 0                               el Raval  Dona  0 anys     203    1     0
# 1                         el Barri Gòtic  Dona  0 anys      59    2     0
# 2                         la Barceloneta  Dona  0 anys      36    3     0
# 3  Sant Pere, Santa Caterina i la Ribera  Dona  0 anys      59    4     0
# 4                          el Fort Pienc  Dona  0 anys      98    5     0
#
#     ref
# 0  anys
# 1  anys
# 2  anys
# 3  anys
# 4  anys

# %%
# Dropping unecessary columns

# %%
padro_merge.drop(["ref"], axis=1, inplace=True)

# %%
padro_merge.drop(["edat"], axis=1, inplace=True)

# %%
padro_merge.head()
# Out:
#     any  codi_districte nom_districte  codi_barri  \
# 0  2020               1  Ciutat Vella           1
# 1  2020               1  Ciutat Vella           2
# 2  2020               1  Ciutat Vella           3
# 3  2020               1  Ciutat Vella           4
# 4  2020               2      Eixample           5
#
#                                nom_barri  sexe  nombre  key  edats
# 0                               el Raval  Dona     203    1      0
# 1                         el Barri Gòtic  Dona      59    2      0
# 2                         la Barceloneta  Dona      36    3      0
# 3  Sant Pere, Santa Caterina i la Ribera  Dona      59    4      0
# 4                          el Fort Pienc  Dona      98    5      0

# %%
# Converting the object edats to int

# %%
padro_merge['edats'] = padro_merge.edats.astype(int)

# %% [markdown]
# #### Total Population by neightborhood

# %%
barri = padro_merge.groupby("nom_barri").sum()

# %%
new_barri = barri.reset_index()

# %%
new_barri.head()
# Out:
#           nom_barri     any  codi_districte  codi_barri  nombre      key  \
# 0     Baró de Viver  408040            1818       11716    2625  1493689
# 1          Can Baró  408040            1414        6868    9331  1488841
# 2       Can Peguera  408040            1616        9494    2234  1491467
# 3         Canyelles  408040            1616        9898    6869  1491871
# 4  Ciutat Meridiana  408040            1616       11110   11091  1493083
#
#    edats
# 0  10100
# 1  10100
# 2  10100
# 3  10100
# 4  10100

# %%
#Llista de barris amb nombre d´habitans
#pd.set_option('display.max_rows', None) to show whole dataset
totals_barri = new_barri[["nom_barri", "nombre"]]

# %%
totals_barri
# Out:
#                         nom_barri  nombre
# 0                   Baró de Viver    2625
# 1                        Can Baró    9331
# 2                     Can Peguera    2234
# 3                       Canyelles    6869
# 4                Ciutat Meridiana   11091
# ..                            ...     ...
# 68  la Vila Olímpica del Poblenou    9385
# 69              la Vila de Gràcia   50926
# 70                      les Corts   46731
# 71                   les Roquetes   16417
# 72                les Tres Torres   16617
#
# [73 rows x 2 columns]

# %% [markdown]
# ### Total Population by district

# %%
districte = padro_merge.groupby("nom_districte").sum()

# %%
new_districte = districte.reset_index()

# %%
#Llista de districtes amb nombre d´habitants

new_districte[["nom_districte", "nombre"]]
# Out:
#          nom_districte  nombre
# 0         Ciutat Vella  108331
# 1             Eixample  270694
# 2               Gràcia  123651
# 3       Horta-Guinardó  174799
# 4            Les Corts   82635
# 5           Nou Barris  174012
# 6          Sant Andreu  151976
# 7           Sant Martí  241691
# 8       Sants-Montjuïc  187584
# 9  Sarrià-Sant Gervasi  151157

# %%
total_districte = new_districte[["nom_districte", "nombre"]]

# %%
total_districte
# Out:
#          nom_districte  nombre
# 0         Ciutat Vella  108331
# 1             Eixample  270694
# 2               Gràcia  123651
# 3       Horta-Guinardó  174799
# 4            Les Corts   82635
# 5           Nou Barris  174012
# 6          Sant Andreu  151976
# 7           Sant Martí  241691
# 8       Sants-Montjuïc  187584
# 9  Sarrià-Sant Gervasi  151157

# %% [markdown]
# ### Total population by age

# %%
mayor_60 = padro_merge[padro_merge["edats"] > 60]

# %%
total_60 = mayor_60.groupby("nom_districte")["nombre"].sum().sort_values()

# %%
total_60df = pd.DataFrame(total_60).reset_index()

# %%
total_60df
# Out:
#          nom_districte  nombre
# 0         Ciutat Vella   16837
# 1            Les Corts   25871
# 2               Gràcia   31981
# 3  Sarrià-Sant Gervasi   39266
# 4          Sant Andreu   40465
# 5       Sants-Montjuïc   46311
# 6           Nou Barris   46393
# 7       Horta-Guinardó   48322
# 8           Sant Martí   60499
# 9             Eixample   72092

# %%
percentage_60 = pd.merge(total_districte, total_60df, on='nom_districte')

# %%
percentage_60 = percentage_60.rename(columns = {"nombre_x":"poblacio_total",
                                                "nombre_y":"poblacio_+60",
                                                })

# %%
percentage_60["%_poblacion_+60"] = ((percentage_60["poblacio_+60"]/percentage_60["poblacio_total"])*100)

# %%
percentage_60.drop(["percentage"], axis=1, inplace=True)

# %%
percentage_60.loc['Total']= percentage_60[["poblacio_total", "poblacio_+60"]].sum()

# %%
percentage_60["+60_%_total"] = (percentage_60["poblacio_+60"]/sum(percentage_60.drop("Total")["poblacio_total"]))*100

# %%
percentage_60.fillna("", inplace=True)

# %%
percentage_60
# Out:
#              nom_districte  poblacio_total  poblacio_+60  %_poblacion_+60  \
# 0             Ciutat Vella        108331.0       16837.0        15.542181
# 1                 Eixample        270694.0       72092.0        26.632286
# 2                   Gràcia        123651.0       31981.0        25.863923
# 3           Horta-Guinardó        174799.0       48322.0        27.644323
# 4                Les Corts         82635.0       25871.0        31.307557
# 5               Nou Barris        174012.0       46393.0        26.660805
# 6              Sant Andreu        151976.0       40465.0        26.625915
# 7               Sant Martí        241691.0       60499.0        25.031549
# 8           Sants-Montjuïc        187584.0       46311.0        24.688140
# 9      Sarrià-Sant Gervasi        151157.0       39266.0        25.976964
# Total                            1666530.0      428037.0        25.684326
#
#        +60_%_total
# 0         1.010303
# 1         4.325875
# 2         1.919017
# 3         2.899558
# 4         1.552387
# 5         2.783808
# 6         2.428099
# 7         3.630238
# 8         2.778888
# 9         2.356153
# Total    25.684326

# %% [markdown]
# ### Population Density

# %%
pop_url = "https://opendata-ajuntament.barcelona.cat/data/dataset/b7ba32eb-806e-4c9c-b0b1-9bab387fe501/resource/08c88565-5b50-47d1-8234-6d3dd2da4c58/download/2019_densitat.csv"

# %%
density = pd.read_csv(pop_url)

# %%
density.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2019               1  Ciutat Vella           1
# 1  2019               1  Ciutat Vella           2
# 2  2019               1  Ciutat Vella           3
# 3  2019               1  Ciutat Vella           4
# 4  2019               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47353            110.0
# 1                         el Barri Gòtic     18629             81.6
# 2                         la Barceloneta     14857            109.5
# 3  Sant Pere, Santa Caterina i la Ribera     22590            111.0
# 4                          el Fort Pienc     32349             92.9
#
#    Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                         49.6                430                     955
# 1                         34.1                228                     546
# 2                         13.5                136                    1097
# 3                         32.4                204                     697
# 4                         33.6                348                     962

# %%
lower_names = [i.lower() for i in density.columns]

# %%
density.columns = lower_names

# %%
district_density =  density.groupby("nom_districte").sum().reset_index()

# %%
district_density
# Out:
#          nom_districte    any  codi_districte  codi_barri  població  \
# 0         Ciutat Vella   8076               4          10    103429
# 1             Eixample  12114              12          45    265910
# 2               Gràcia  10095              30         150    121798
# 3       Horta-Guinardó  22209              77         418    171495
# 4            Les Corts   6057              12          60     81974
# 5           Nou Barris  26247             104         650    170669
# 6          Sant Andreu  14133              63         420    149821
# 7           Sant Martí  20190             100         685    238315
# 8       Sants-Montjuïc  16152              24         116    184091
# 9  Sarrià-Sant Gervasi  12114              30         147    149260
#
#    superfície (ha)  superfície residencial (ha)  densitat (hab/ha)  \
# 0            412.1                        129.6                998
# 1            746.4                        372.1               2300
# 2            422.4                        202.4               1461
# 3           1191.9                        289.9               2087
# 4            601.0                        177.9                496
# 5            805.1                        232.7               3439
# 6            658.9                        190.5               1795
# 7           1038.7                        288.6               2487
# 8           2267.7                        251.5               2377
# 9           1991.5                        610.9               1047
#
#    densitat neta (hab/ha)
# 0                    3295
# 1                    4796
# 2                    3118
# 3                    6423
# 4                    1617
# 5                    8914
# 6                    5476
# 7                    8526
# 8                    6116
# 9                    2043

# %%
real_pop = new_districte[["nom_districte", "nombre"]]

# %%
real_density = pd.merge(district_density, real_pop, on='nom_districte')

# %%
real_density
# Out:
#          nom_districte    any  codi_districte  codi_barri  població  \
# 0         Ciutat Vella   8076               4          10    103429
# 1             Eixample  12114              12          45    265910
# 2               Gràcia  10095              30         150    121798
# 3       Horta-Guinardó  22209              77         418    171495
# 4            Les Corts   6057              12          60     81974
# 5           Nou Barris  26247             104         650    170669
# 6          Sant Andreu  14133              63         420    149821
# 7           Sant Martí  20190             100         685    238315
# 8       Sants-Montjuïc  16152              24         116    184091
# 9  Sarrià-Sant Gervasi  12114              30         147    149260
#
#    superfície (ha)  superfície residencial (ha)  densitat (hab/ha)  \
# 0            412.1                        129.6                998
# 1            746.4                        372.1               2300
# 2            422.4                        202.4               1461
# 3           1191.9                        289.9               2087
# 4            601.0                        177.9                496
# 5            805.1                        232.7               3439
# 6            658.9                        190.5               1795
# 7           1038.7                        288.6               2487
# 8           2267.7                        251.5               2377
# 9           1991.5                        610.9               1047
#
#    densitat neta (hab/ha)  nombre
# 0                    3295  108331
# 1                    4796  270694
# 2                    3118  123651
# 3                    6423  174799
# 4                    1617   82635
# 5                    8914  174012
# 6                    5476  151976
# 7                    8526  241691
# 8                    6116  187584
# 9                    2043  151157

# %%
pop_2020 = real_density.drop(["població"], axis=1)

# %%
pop_2020['Km2'] = pop_2020["superfície (ha)"] * 0.01

# %%
pop_2020["density"] = (pop_2020["nombre"]/pop_2020["Km2"]).round()

# %%
pop_2020.loc['Total']= pop_2020[["superfície (ha)", "superfície residencial (ha)", "nombre", "Km2", "density"]].sum()

# %%
pop_2020.drop(["densitat neta (hab/ha)"], axis=1, inplace=True)

# %%
pop_2020.drop(["densitat (hab/ha)"], axis=1, inplace=True)

# %%
pop_2020.drop(["codi_districte", "codi_barri", "any",], axis=1, inplace=True)

# %%
pop_2020.fillna("", inplace=True)

# %%
pop_2020
# Out:
#              nom_districte  superfície (ha)  superfície residencial (ha)  \
# 0             Ciutat Vella            412.1                        129.6
# 1                 Eixample            746.4                        372.1
# 2                   Gràcia            422.4                        202.4
# 3           Horta-Guinardó           1191.9                        289.9
# 4                Les Corts            601.0                        177.9
# 5               Nou Barris            805.1                        232.7
# 6              Sant Andreu            658.9                        190.5
# 7               Sant Martí           1038.7                        288.6
# 8           Sants-Montjuïc           2267.7                        251.5
# 9      Sarrià-Sant Gervasi           1991.5                        610.9
# Total                               10135.7                       2746.1
#
#           nombre      Km2   density
# 0       108331.0    4.121   26288.0
# 1       270694.0    7.464   36267.0
# 2       123651.0    4.224   29273.0
# 3       174799.0   11.919   14666.0
# 4        82635.0    6.010   13750.0
# 5       174012.0    8.051   21614.0
# 6       151976.0    6.589   23065.0
# 7       241691.0   10.387   23269.0
# 8       187584.0   22.677    8272.0
# 9       151157.0   19.915    7590.0
# Total  1666530.0  101.357  204054.0

# %%
pop_2020["density_%"] = ((pop_2020["poblacio_+60"]/pop_2020["poblacio_total"])*100).round()
